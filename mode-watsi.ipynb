# %%
import numpy as np 
import pandas as pd

# %%
cities = ["Tokyo", "Paris", "Athens", "New York", "Madrid", "London", "Tel Aviv"]

# %%
df = pd.read_csv("watsi_dataset.csv")

# %%
df.head(5)
# Out:
#                                             referrer            timestamp  \
# 0                            https://www.google.com/  2016-02-05 00:48:23
# 1  https://themeteorchef.com/snippets/making-use-...  2016-02-24 23:12:10
# 2                                 https://watsi.org/  2015-12-25 17:59:35
# 3                                                NaN  2016-02-05 21:19:30
# 4                  https://watsi.org/fund-treatments  2016-02-14 19:30:08
#
#                                                title  \
# 0  Watsi | Fund medical treatments for people aro...
# 1                            Watsi | The Meteor Chef
# 2  Watsi | Give the gift of health with a Watsi G...
# 3  Watsi | Fund medical treatments for people aro...
# 4  Watsi | Fund medical treatments for people aro...
#
#                                       url  \
# 0                      https://watsi.org/
# 1  https://watsi.org/team/the-meteor-chef
# 2            https://watsi.org/gift-cards
# ...

# %%
# df = df.fillna('')

# %%
# use .iloc method to select a given row

df[:5][["timestamp", "url"]]
# Out:
#              timestamp                                     url
# 0  2016-02-05 00:48:23                      https://watsi.org/
# 1  2016-02-24 23:12:10  https://watsi.org/team/the-meteor-chef
# 2  2015-12-25 17:59:35            https://watsi.org/gift-cards
# 3  2016-02-05 21:19:30                      https://watsi.org/
# 4  2016-02-14 19:30:08                      https://watsi.org/

# %%
df[["timestamp", "url"]][:5]
# Out:
#              timestamp                                     url
# 0  2016-02-05 00:48:23                      https://watsi.org/
# 1  2016-02-24 23:12:10  https://watsi.org/team/the-meteor-chef
# 2  2015-12-25 17:59:35            https://watsi.org/gift-cards
# 3  2016-02-05 21:19:30                      https://watsi.org/
# 4  2016-02-14 19:30:08                      https://watsi.org/

# %%
df[['title','referrer']].value_counts()[:10]
# Out:
# title                                                                                                 referrer
# Watsi | Fund a medical treatment on Watsi. 100% of your donation directly funds a medical treatment.  https://watsi.org/                   297
# Watsi | Fund medical treatments for people around the world                                           https://www.google.com/              153
# Watsi | About Us                                                                                      https://watsi.org/                    93
# Watsi | Fund medical treatments for people around the world                                           https://www.google.co.in/             53
# Watsi | How Watsi works                                                                               https://watsi.org/                    46
# Watsi | Join Watsi's Universal Fund                                                                   https://watsi.org/                    39
# ...

# %%
df['referrer'].value_counts()[:20]
# Out:
# https://watsi.org/                          642
# https://watsi.org/fund-treatments           315
# https://www.google.com/                     215
# https://watsi.org/fund-treatments?page=2    139
# https://watsi.org/about                     107
# http://blog.watsi.org/                       90
# https://watsi.org/universal-fund             79
# https://www.facebook.com/                    69
# https://watsi.org/how                        58
# http://m.facebook.com                        57
# https://www.google.co.in/                    55
# https://watsi.org/fund-treatments?page=3     47
# https://watsi.org/fund-treatments?page=4     31
# https://watsi.org/gift-cards                 26
# https://www.reddit.com/                      24
# https://www.google.ca/                       20
# https://www.google.co.uk/                    19
# https://t.co/oA3AsouPDj                      18
# https://www.google.com.au/                   16
# https://www.google.com                       16
# ...

# %%
df['title'].value_counts()[:10].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df['website_section'].value_counts()[:10].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df['referrer_domain'].value_counts()[:10].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df['platform'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
homepage_df = df[df['title']=='Watsi | Fund medical treatments for people around the world']
homepage_df['referrer_domain'] = homepage_df['referrer_domain'].fillna('unknown')

# %%
homepage_df['referrer_domain'].value_counts()[:15].plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df[df['referrer_domain'] == 'reddit.com']['title'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>
